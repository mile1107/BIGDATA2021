# %% [markdown]
# # ALGORITMOS DE BoW

# %%
# Leer el archivo con textFile
arquivo = os.path.join('Data', 'text_500lines.txt')
twittsRDD = (sc.textFile(arquivo, 4))

# %% [markdown]
# ## - Bag of Words

# %%
import re
def bagOfWords(array):
    """Elimina la puntuación, cambia a minúsculas y elimina los espacios iniciales y finales, 
        y solo guarda palabras de más de 2 letras.
    Args:
        array: arreglo de strings.

    Returns:
        array: arreglo de strings limpios y preprocesados.
    """
    new = []
    for i in array:
        norm = re.sub(r'[^A-Za-z0-9 ]', '', i).strip().lower()
        if (len(norm) > 2):
            new.append(norm)
    return new

# %%
# Separar cada string (línea del texto) en conjunto de palabras
twittsPalavrasRDD = twittsRDD.map(lambda x: x.split())
twittsPalavrasRDD = twittsPalavrasRDD.map(lambda x: bagOfWords(x))
# Mostrar el RDD del texto creado 
print(twittsPalavrasRDD.collect())
# Out:
# [['protester', 'stage', 'diein', 'protest', 'store', 'nyc', 'anger', 'misplace', 'retweet', 'agree'], ['apple', 'intraday', 'comment', 'update', 'range', 'premium', 'user', 'aapl', 'stockaction', 'trading', 'stock', 'mkt'], ['ios', 'app', '2014', 'name', 'elevate', 'brain', 'training', 'iphone', 'app'], ['shit'], ['founder', 'attack', 'boss', 'ridiculous', 'comment'], ['evidence', 'factcheckthis'], ['educate'], ['hard', 'reach', 'buy', 'suicide', 'squad', 'comicstrip', 'apple', 'store', 'turkey'], ['delete', 'music', 'customer', 'ipod'], ['apple', 'intraday', 'comment', 'update', 'range', 'premium', 'user', 'aapl', 'stockaction', 'trading', 'stock', 'mkt'], ['studio', '45000', 'outlet', 'computer', 'need', 'battery', 'future'], ['apple', 'great', 'business', 'aapl', 'investwall', 'aapl'], ['dear', 'love', 'iphone', 'plus', 'lot', 'great', 'achievement', 'iphone', 'reboot', 'day', 'fail'], ['survey', 'feedback', 'iwatch', 'positioning', 'fashion', 'accessory', 'geek', 'centric', 'gadget'], ['similar', 'cloud', 'backup', 'picture', 'onlinefootprint', 'modicumofprudence'], ['protester', 'stage', 'diein', 'protest', 'store', 'nyc', 'anger', 'misplace', 'retweet', 'agree'], ['fuck', 'make', 'shit', 'product'], ['try', 'turn', 'problem'], ['macbook', 'pro', 'annoying', 'asus', 'window', 'computer', 'freezing', 'laggy', 'etc', 'excellence'], ['speak', 'wearable', 'new', 'chargehr', 'amp', 'iphone', 'want', 'eat', 'latke', 'run', 'place', 'tlchat'], ['forbe', 'whoop', 'plaintiff', 'apple', 'tell', 'court', 'ipod', 'owner', 'class', 'represent', 'aapl'], ['thanks', '3way', 'call', 'facetime', 'call', 'ability', 'device', 'seamlessly'], ['mkt', 'final', 'aapl', 'putcallratio', 'monday', 'december', '2014'], ['julian', 'robertson', 'bullish', 'apple', 'inc', 'aapl'], ['apple', 'intraday', 'comment', 'update', 'range', 'premium', 'user', 'aapl', 'stockaction', 'trading', 'stock', 'mkt'], ['new', 'problem', 'airport', 'board', 'pass', 'phone', 'hold', 'scanner', 'security', 'applepay', 'credit', 'card', 'take', 'screen'], ['help', 'mac', 'memory', 'clear', 'ask', 'password', 'old'], ['ask', 'use', 'voice', 'attribute', 'dude', 'ace', 'vocal', 'clone'], ['fuck', 'fuck', 'hate'], ['apple', 'want', 'commute', 'easy', 'accord', 'new', 'patent', 'aapl'], ['studio', '45000', 'outlet', 'computer', 'need', 'battery', 'future'], ['need', 'help', 'apple', 'iphone6', 'amp', 'iphone6plus', 'checkitout'], ['invest', 'terabyte', 'storage'], ['ceo', 'warn', 'wearable', 'maker', 'tech', 'need', 'productivity', 'novelty', 'like', 'siri'], ['gva', 'lounge', 'sight', 'mac', 'undetermined', 'number', 'ipxs', 'aapl'], ['afp', 'request', 'apple', 'reveal', 'warrant', 'pushback', 'tax', 'evader', 'rip', 'aussie'], ['protester', 'stage', 'diein', 'protest', 'store', 'nyc', 'anger', 'misplace', 'retweet', 'agree'], ['yeah', 'monarchywpb', 'sticker', 'ride', 'boommovement'], ['afternoon', 'tea', 'ipadair2', 'touchpoint', 'reward', 'visit', 'info'], ['drain', 'battery', 'fix'], ['apple', 'ceo', 'visit'], ['promoproduct', 'supplier', 'carry', 'brandable', 'compliant', 'adapter', 'headsaregoingtoroll'], ['new', 'sony'], ['apple', 'pay', 'service', 'lead', 'price', 'target', 'upgrade', 'apple', 'inc', 'aapl', 'aapl'], ['studio', '45000', 'outlet', 'computer', 'need', 'battery', 'future'], ['canal', 'street', 'knockoff', 'cmonman', 'pay', 'lightning', 'cord'], ['excited', 'name', 'app', 'store', 'best', '2014', 'list', 'year', 'apple'], ['gold', 'macbook'], ['studio', '45000', 'outlet', 'computer', 'need', 'battery', 'future'], ['hey', 'teach', 'people', 'use', 'pay'], ['protester', 'stage', 'diein', 'protest', 'store', 'nyc', 'anger', 'misplace', 'retweet', 'agree'], ['well', 'iphone', 'app', 'year', 'accord', 'apple', 'monday', 'december'], ['protester', 'stage', 'diein', 'protest', 'store', 'nyc', 'anger', 'misplace', 'retweet', 'agree'], ['make', 'smart', 'elevate', 'app', 'year', 'congratulation', 'team'], ['final', 'aapl', 'putcallratio', 'monday', 'december', '20 ...

# %% [markdown]
# ## - TF (Term Frecuency)

# %%
# Librería para usar funciones matemáticas
import math

# Función TF
def tf(lista):
    """Calculates el TF de cada palabra de la lista.

    Args:
        lista (array): Arreglo de palabras (strings).

    Returns:
        tuplas (array of tuples): Arreglo de tuplas (palabra,tf de la palabra).
    """
    tuplas = [] 
    cantidad = len(lista) # Obtiene la cantidad de elementos de la lista
    # Recorre cada elemento o palabra de la lista y halla su tf
    for i in lista:
        if(i not in [j[0] for j in tuplas]):
            tuplas.append((i,1 + math.log10(lista.count(i)/cantidad))) # TF de una palabra
    return tuplas

# %%
# Halla el TF de todas las palabras de cada línea de todo el corpus
tfTwitts = twittsPalavrasRDD.map(lambda x: tf(x))

print(tfTwitts.collect())
# Out:
# [[('protester', 0.0), ('stage', 0.0), ('diein', 0.0), ('protest', 0.0), ('store', 0.0), ('nyc', 0.0), ('anger', 0.0), ('misplace', 0.0), ('retweet', 0.0), ('agree', 0.0)], [('apple', -0.07918124604762489), ('intraday', -0.07918124604762489), ('comment', -0.07918124604762489), ('update', -0.07918124604762489), ('range', -0.07918124604762489), ('premium', -0.07918124604762489), ('user', -0.07918124604762489), ('aapl', -0.07918124604762489), ('stockaction', -0.07918124604762489), ('trading', -0.07918124604762489), ('stock', -0.07918124604762489), ('mkt', -0.07918124604762489)], [('ios', 0.04575749056067513), ('app', 0.34678748622465627), ('2014', 0.04575749056067513), ('name', 0.04575749056067513), ('elevate', 0.04575749056067513), ('brain', 0.04575749056067513), ('training', 0.04575749056067513), ('iphone', 0.04575749056067513)], [('shit', 1.0)], [('founder', 0.30102999566398125), ('attack', 0.30102999566398125), ('boss', 0.30102999566398125), ('ridiculous', 0.30102999566398125), ('comment', 0.30102999566398125)], [('evidence', 0.6989700043360187), ('factcheckthis', 0.6989700043360187)], [('educate', 1.0)], [('hard', 0.04575749056067513), ('reach', 0.04575749056067513), ('buy', 0.04575749056067513), ('suicide', 0.04575749056067513), ('squad', 0.04575749056067513), ('comicstrip', 0.04575749056067513), ('apple', 0.04575749056067513), ('store', 0.04575749056067513), ('turkey', 0.04575749056067513)], [('delete', 0.3979400086720376), ('music', 0.3979400086720376), ('customer', 0.3979400086720376), ('ipod', 0.3979400086720376)], [('apple', -0.07918124604762489), ('intraday', -0.07918124604762489), ('comment', -0.07918124604762489), ('update', -0.07918124604762489), ('range', -0.07918124604762489), ('premium', -0.07918124604762489), ('user', -0.07918124604762489), ('aapl', -0.07918124604762489), ('stockaction', -0.07918124604762489), ('trading', -0.07918124604762489), ('stock', -0.07918124604762489), ('mkt', -0.07918124604762489)], [('studio', 0.1549019599857432), ('45000', 0.1549019599857432), ('outlet', 0.1549019599857432), ('computer', 0.1549019599857432), ('need', 0.1549019599857432), ('battery', 0.1549019599857432), ('future', 0.1549019599857432)], [('apple', 0.22184874961635637), ('great', 0.22184874961635637), ('business', 0.22184874961635637), ('aapl', 0.5228787452803376), ('investwall', 0.22184874961635637)], [('dear', -0.04139268515822492), ('love', -0.04139268515822492), ('iphone', 0.2596373105057561), ('plus', -0.04139268515822492), ('lot', -0.04139268515822492), ('great', -0.04139268515822492), ('achievement', -0.04139268515822492), ('reboot', -0.04139268515822492), ('day', -0.04139268515822492), ('fail', -0.04139268515822492)], [('survey', 0.04575749056067513), ('feedback', 0.04575749056067513), ('iwatch', 0.04575749056067513), ('positioning', 0.04575749056067513), ('fashion', 0.04575749056067513), ('accessory', 0.04575749056067513), ('geek', 0.04575749056067513), ('centric', 0.04575749056067513), ('gadget', 0.04575749056067513)], [('similar', 0.22184874961635637), ('cloud', 0.22184874961635637), ('backup', 0.22184874961635637), ('picture', 0.22184874961635637), ('onlinefootprint', 0.22184874961635637), ('modicumofprudence', 0.22184874961635637)], [('protester', 0.0), ('stage', 0.0), ('diein', 0.0), ('protest', 0.0), ('store', 0.0), ('nyc', 0.0), ('anger', 0.0), ('misplace', 0.0), ('retweet', 0.0), ('agree', 0.0)], [('fuck', 0.3979400086720376), ('make', 0.3979400086720376), ('shit', 0.3979400086720376), ('product', 0.3979400086720376)], [('try', 0.5228787452803376), ('turn', 0.5228787452803376), ('problem', 0.5228787452803376)], [('macbook', 0.0), ('pro', 0.0), ('annoying', 0.0), ('asus', 0.0), ('window', 0.0), ('computer', 0.0), ('freezing', 0.0), ('laggy', 0.0), ('etc', 0.0), ('excellence', 0.0)], [('speak', -0.07918124604762489), ('wearable', -0.07918124604762489), ('new', -0.07918124604762489), ('chargehr', -0.07918124604762489), ('amp', -0.07918124604762489), ('iphone', -0.07918124604762489), ('want', -0.07918124604 ...

# %% [markdown]
# ## - IDF (Inverse Document Frequency)

# %%
# Halla el número de líneas del texto
numDocs = tfTwitts.count()

print(numDocs)
# Out:
# 500

# %%
# Halla el IDF de cada palabra de todo el texto
idfTwitts = tfTwitts.flatMap(lambda x: [(i[0],1) for i in x]).reduceByKey(lambda x,y: x+y).map(lambda x: (x[0],math.log10(1 + (numDocs/x[1])))).collect()

print(idfTwitts)
# Out:
# [('stage', 1.375247822180056), ('store', 1.150998679049579), ('nyc', 1.3222192947339193), ('aapl', 0.6724399567969696), ('stockaction', 1.752475272897434), ('2014', 1.5961740128049795), ('name', 1.8599099193190791), ('boss', 2.699837725867246), ('educate', 2.699837725867246), ('customer', 2.0043213737826426), ('business', 2.2244467303362647), ('investwall', 2.699837725867246), ('reboot', 2.699837725867246), ('feedback', 2.699837725867246), ('iwatch', 2.399673721481038), ('accessory', 2.699837725867246), ('onlinefootprint', 2.699837725867246), ('turn', 2.100370545117563), ('asus', 2.699837725867246), ('freezing', 2.399673721481038), ('laggy', 2.699837725867246), ('excellence', 2.699837725867246), ('tell', 1.8027737252919758), ('owner', 2.699837725867246), ('facetime', 2.399673721481038), ('seamlessly', 2.699837725867246), ('inc', 1.414973347970818), ('airport', 2.699837725867246), ('board', 2.399673721481038), ('security', 2.100370545117563), ('card', 2.699837725867246), ('clone', 2.699837725867246), ('commute', 2.699837725867246), ('accord', 2.2244467303362647), ('iphone6', 1.6670282149764877), ('invest', 2.699837725867246), ('terabyte', 2.699837725867246), ('ceo', 2.0043213737826426), ('maker', 2.699837725867246), ('like', 1.630088714928206), ('gva', 2.699837725867246), ('reveal', 2.100370545117563), ('pushback', 2.699837725867246), ('rip', 2.699837725867246), ('aussie', 2.699837725867246), ('monarchywpb', 2.699837725867246), ('afternoon', 2.699837725867246), ('pay', 1.752475272897434), ('service', 2.0043213737826426), ('cord', 2.2244467303362647), ('best', 2.399673721481038), ('smart', 2.399673721481038), ('team', 2.2244467303362647), ('trader', 2.399673721481038), ('darkpool', 2.699837725867246), ('switch', 2.699837725867246), ('free', 2.0043213737826426), ('macmail', 2.699837725867246), ('give', 2.2244467303362647), ('money', 2.0043213737826426), ('mary', 2.699837725867246), ('green', 2.2244467303362647), ('leadership', 2.699837725867246), ('charge', 2.399673721481038), ('library', 2.699837725867246), ('sync', 2.699837725867246), ('uploaded', 2.699837725867246), ('genius', 2.699837725867246), ('say', 1.9259992664561554), ('wonder', 2.699837725867246), ('think', 1.8599099193190791), ('bmo', 2.699837725867246), ('work', 1.414973347970818), ('good', 1.6670282149764877), ('record', 2.699837725867246), ('quarter', 2.399673721481038), ('sale', 2.0043213737826426), ('piss', 2.699837725867246), ('long', 1.9259992664561554), ('job', 1.9259992664561554), ('idk', 2.699837725867246), ('right', 2.100370545117563), ('check', 2.399673721481038), ('opportunity', 2.399673721481038), ('simulator', 2.699837725867246), ('social', 2.399673721481038), ('coverage', 2.699837725867246), ('nofear', 2.399673721481038), ('idea', 2.100370545117563), ('ban', 2.699837725867246), ('school', 2.699837725867246), ('anonymous', 2.699837725867246), ('threat', 2.399673721481038), ('introduction', 2.699837725867246), ('edtech', 2.699837725867246), ('earth', 2.399673721481038), ('dun', 2.699837725867246), ('ironic', 2.699837725867246), ('ie8', 2.699837725867246), ('flog', 2.699837725867246), ('watch', 1.6670282149764877), ('rampd', 2.699837725867246), ('minister', 2.699837725867246), ('chinese', 2.699837725867246), ('official', 2.399673721481038), ('global', 2.699837725867246), ('150', 2.399673721481038), ('anti', 2.699837725867246), ('result', 2.699837725867246), ('mobility', 2.699837725867246), ('loyal', 2.699837725867246), ('trial', 2.2244467303362647), ('94986', 2.699837725867246), ('daughter', 2.699837725867246), ('feel', 2.699837725867246), ('mean', 2.399673721481038), ('demand', 2.2244467303362647), ('join', 2.399673721481038), ('barclay', 2.699837725867246), ('14000', 2.699837725867246), ('unacceptable', 2.699837725867246), ('williamsburg', 2.399673721481038), ('happen', 2.100370545117563), ('corporate', 2.399673721481038), ('dare', 2.699837725867246), ('sign', 2.399673721481038), ('lap', 2.699837725867246), ('question', 2.699837725867246), ('xperia', 2. ...

# %% [markdown]
# ## - TF-IDF (Term Frequency - Inverse Document Frequency)

# %%
def buscar(value,lista):
    """Función buscar un elemento en una lista de tuplas.

    Args:
        lista : Lista de tuplas.
        value (string): Palabra para buscar en una lista de tuplas.
    Returns:
        val (float): Devuelve un valor de una tupla buscada.
    """
    val = 0
    for i in lista:
        if (value == i[0]):
            val = i[1]
    return val

# %%
# Halla el td-idf de una palabra multiplicando el valor de su tf y su idf de dicha palabra
tfidf = tfTwitts.map(lambda x: [(i[0], i[1]*float(buscar(i[0],idfTwitts))) for i in x])

print(tfidf.collect())
# Out:
# [[('protester', 0.0), ('stage', 0.0), ('diein', 0.0), ('protest', 0.0), ('store', 0.0), ('nyc', 0.0), ('anger', 0.0), ('misplace', 0.0), ('retweet', 0.0), ('agree', 0.0)], [('apple', -0.05265090382878352), ('intraday', -0.12907245561618694), ('comment', -0.1387631757756703), ('update', -0.11203935281650888), ('range', -0.16630995692413775), ('premium', -0.14274586991053725), ('user', -0.13199737125838618), ('aapl', -0.05324463367139509), ('stockaction', -0.1387631757756703), ('trading', -0.13199737125838618), ('stock', -0.10889383618449928), ('mkt', -0.12907245561618694)], [('ios', 0.08249040171808072), ('app', 0.5143002759613143), ('2014', 0.0730369173241188), ('name', 0.0851048105769488), ('elevate', 0.10178510026608628), ('brain', 0.10980304765936875), ('training', 0.10980304765936875), ('iphone', 0.044989048661627375)], [('shit', 1.8599099193190791)], [('founder', 0.81273213891127), ('attack', 0.7223737699724067), ('boss', 0.81273213891127), ('ridiculous', 0.81273213891127), ('comment', 0.527547623801549)], [('evidence', 1.5548215407483816), ('factcheckthis', 1.8871055869559759)], [('educate', 2.699837725867246)], [('hard', 0.09610768539213696), ('reach', 0.12353779925672512), ('buy', 0.08018887075742091), ('suicide', 0.12353779925672512), ('squad', 0.12353779925672512), ('comicstrip', 0.12353779925672512), ('apple', 0.030426058633979295), ('store', 0.05266681119196065), ('turkey', 0.12353779925672512)], [('delete', 0.7664321647959005), ('music', 0.7401325694230431), ('customer', 0.7975996648646151), ('ipod', 0.6973800252943364)], [('apple', -0.05265090382878352), ('intraday', -0.12907245561618694), ('comment', -0.1387631757756703), ('update', -0.11203935281650888), ('range', -0.16630995692413775), ('premium', -0.14274586991053725), ('user', -0.13199737125838618), ('aapl', -0.05324463367139509), ('stockaction', -0.1387631757756703), ('trading', -0.13199737125838618), ('stock', -0.10889383618449928), ('mkt', -0.12907245561618694)], [('studio', 0.17666942751011083), ('45000', 0.17509091617794775), ('outlet', 0.17666942751011083), ('computer', 0.16510836778296767), ('need', 0.15662385093281028), ('battery', 0.16255044012141998), ('future', 0.17059838842782601)], [('apple', 0.14751646082408454), ('great', 0.38878444802587864), ('business', 0.49349072571329256), ('aapl', 0.3516045608863639), ('investwall', 0.5989556236507156)], [('dear', -0.07698666571303416), ('love', -0.07253965721861778), ('iphone', 0.25527701483604204), ('plus', -0.09207582316005185), ('lot', -0.09207582316005185), ('great', -0.07253965721861778), ('achievement', -0.11175353296512086), ('reboot', -0.11175353296512086), ('day', -0.07698666571303416), ('fail', -0.08693997668966053)], [('survey', 0.12353779925672512), ('feedback', 0.12353779925672512), ('iwatch', 0.10980304765936875), ('positioning', 0.12353779925672512), ('fashion', 0.12353779925672512), ('accessory', 0.12353779925672512), ('geek', 0.12353779925672512), ('centric', 0.12353779925672512), ('gadget', 0.12353779925672512)], [('similar', 0.5989556236507156), ('cloud', 0.5323646145977968), ('backup', 0.5323646145977968), ('picture', 0.5989556236507156), ('onlinefootprint', 0.5989556236507156), ('modicumofprudence', 0.5989556236507156)], [('protester', 0.0), ('stage', 0.0), ('diein', 0.0), ('protest', 0.0), ('store', 0.0), ('nyc', 0.0), ('anger', 0.0), ('misplace', 0.0), ('retweet', 0.0), ('agree', 0.0)], [('fuck', 0.6003043294494602), ('make', 0.7401325694230431), ('shit', 0.7401325694230431), ('product', 0.8358214729385753)], [('try', 0.9163320718274276), ('turn', 1.09823911525485), ('problem', 0.972507364948014)], [('macbook', 0.0), ('pro', 0.0), ('annoying', 0.0), ('asus', 0.0), ('window', 0.0), ('computer', 0.0), ('freezing', 0.0), ('laggy', 0.0), ('etc', 0.0), ('excellence', 0.0)], [('speak', -0.19000915537460975), ('wearable', -0.16630995692413775), ('new', -0.11944726284801986), ('chargehr', -0.21377651526055444), ('amp', -0.13520753425719684), ('iphone', -0.0778514924633211), ('want', -0.12 ...

# %% [markdown]
# ## - N-grams y getNgrams

# %% [markdown]
# **Generar 'ngrams' a partir de una secuencia de tokens**

# %%
def ngrams(string, n):
    """Función en el que dado un string y un número n, se convierte en un arreglo de palabras,
        y luego se recupera una lista de n-gramas.

    Args:
        string : Una línea del texto.
        n (int): Valor entero para los gramas.
    Returns:
        val (float): Arreglo de ngramas generado.
    """
    listaPalabras = string.split()
    ngramas = []
    for i in range(len(listaPalabras)-(n-1)):
        ngramas.append(' '.join(listaPalabras[i:i+n]))
    return ngramas

# %% [markdown]
# **Generar 'ngrams' para cada línea del corpus**

# %%
getNgramsRDD =twittsRDD.map(lambda x: ngrams(x, 2))
print(getNgramsRDD.collect())
# Out:
# [['Protester stage', 'stage diein', 'diein protest', 'protest store', 'store nyc', 'nyc anger', 'anger misplace', 'misplace retweet', 'retweet agree'], ['apple intraday', 'intraday comment', 'comment update', 'update range', 'range premium', 'premium user', 'user aapl', 'aapl stockaction', 'stockaction trading', 'trading stock', 'stock mkt'], ['ios app', 'app 2014', '2014 name', 'name elevate', 'elevate brain', 'brain training', 'training iphone', 'iphone app'], [], ['founder attack', 'attack boss', 'boss ridiculous', 'ridiculous comment', 'comment ad'], ['evidence factcheckthis'], [], ['hard reach', 'reach buy', 'buy suicide', 'suicide squad', 'squad comic_strip', 'comic_strip apple', 'apple store', 'store turkey'], ['delete music', 'music customer', 'customer ipod'], ['apple intraday', 'intraday comment', 'comment update', 'update range', 'range premium', 'premium user', 'user aapl', 'aapl stockaction', 'stockaction trading', 'trading stock', 'stock mkt'], ['studio 45,000', '45,000 outlet', 'outlet computer', 'computer need', 'need battery', 'battery future'], ['apple great', 'great business', 'business aapl', 'aapl investwall', 'investwall aapl'], ['dear love', 'love iphone', 'iphone plus', 'plus lot', 'lot great', 'great achievement', 'achievement iphone', 'iphone reboot', 'reboot day', 'day fail'], ['survey feedback', 'feedback iwatch', 'iwatch positioning', 'positioning fashion', 'fashion accessory', 'accessory geek', 'geek centric', 'centric gadget'], ['similar cloud', 'cloud backup', 'backup picture', 'picture onlinefootprint', 'onlinefootprint modicumofprudence'], ['protester stage', 'stage diein', 'diein protest', 'protest store', 'store nyc', 'nyc anger', 'anger misplace', 'misplace retweet', 'retweet agree'], ['fuck make', 'make shit', 'shit product'], ['try turn', 'turn problem'], ['macbook pro', 'pro annoying', 'annoying asus', 'asus window', 'window computer', 'computer freezing', 'freezing laggy', 'laggy etc', 'etc excellence'], ['speak wearable', 'wearable new', 'new chargehr', 'chargehr amp', 'amp iphone', 'iphone want', 'want eat', 'eat latke', 'latke run', 'run place', 'place tl_chat'], ['forbe whoop', 'whoop plaintiff', 'plaintiff apple', 'apple tell', 'tell court', 'court ipod', 'ipod owner', 'owner class', 'class represent', 'represent aapl'], ['thanks 3-way', '3-way call', 'call facetime', 'facetime call', 'call ability', 'ability device', 'device seamlessly'], ['mkt final', 'final aapl', 'aapl putcallratio', 'putcallratio monday', 'monday december', 'december 2014'], ['julian robertson', 'robertson bullish', 'bullish apple', 'apple inc', 'inc aapl'], ['apple intraday', 'intraday comment', 'comment update', 'update range', 'range premium', 'premium user', 'user aapl', 'aapl stockaction', 'stockaction trading', 'trading stock', 'stock mkt'], ['new problem', 'problem airport', 'airport board', 'board pass', 'pass phone', 'phone hold', 'hold scanner', 'scanner security', 'security applepay', 'applepay credit', 'credit card', 'card take', 'take screen'], ['help mac', 'mac memory', 'memory clear', 'clear ask', 'ask password', 'password old'], ['ask use', 'use voice', 'voice attribute', 'attribute dude', 'dude ace', 'ace vocal', 'vocal clone'], ['fuck fuck', 'fuck hate'], ['apple want', 'want commute', 'commute easy', 'easy accord', 'accord new', 'new patent', 'patent aapl'], ['studio 45,000', '45,000 outlet', 'outlet computer', 'computer need', 'need battery', 'battery future'], ['need help', 'help apple', 'apple iphone6', 'iphone6 amp', 'amp iphone6plus', 'iphone6plus checkitout'], ['invest terabyte', 'terabyte storage'], ['ceo warn', 'warn wearable', 'wearable maker', 'maker tech', 'tech need', 'need productivity', 'productivity novelty', 'novelty like', 'like siri'], ['gva lounge', 'lounge sight', 'sight mac', 'mac pc', 'pc undetermined', 'undetermined number', 'number ipxs', 'ipxs aapl'], ['afp request', 'request apple', 'apple reveal', 'reveal warrant', 'warrant pushback', 'pushback tax', 'tax evader',  ...
